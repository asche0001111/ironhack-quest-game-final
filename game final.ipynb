# %%
# Initial conditions
key_a = False
is_door_a_unlocked = False
key_a_status = "NO KEY"
key_b = False
is_door_b_unlocked = False
key_b_status = "NO KEY"
key_c = False
is_door_c_unlocked = False
key_c_status = "NO KEY"
key_d = False
is_door_d_unlocked = False
key_d_status = "NO KEY"
secrets_found = 0
current_moves = 1
secret_knowledge = False
room_1_content = {
    "couch": "As you decide to rummage through the couch you've woken up on, all you can find is cigarette butts in between the couch cushions.",
    "painting": "You lay your eyes upon a crackling oil painting of a decrepit old man, staring menacingly into the observer's gaze. You take it off the wall",
    "piano": "key",
    "wardrobe": "note",
    "door a": "locked"
}

bedroom_1_content = ["cabinet", "rug", "mirror", "door a", "door b", "door c", "queen bed"]

bedroom_2_content = ["carpet", "sewing machine", "bookshelf", "double bed", "dresser", "door b"]

living_room_content = ["dining table", "chair 1", "chair 2", "chair 3", "chair 4", "fireplace", "door c", "door d"]

bed = ["left pillow", "right pillow", "blanket", "sheets", "mattress", "bedframe"]

dresser = ["top shelf", "middle shelf", "bottom shelf"]

def room_1_introduction():
    print("""
         ____________________________________
        |\                                    \
        | \                                    \
        |  \____________________________________\
        |  |       __---_ _---__                |
        |  |      |======|=====|                |
        |  |      |======|=====|                |
        |  |  ____|__---_|_---_|______________  |
        |  | |                                | |
        |   \ \                                \ \
        |  \ ||\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\| |  
        |  |\  ,--------------------------------  |
        |  ||| |                               || |
         \ ||| |           -  -                || |
          \'|| |-----------\\-\\---------------|| |
            \|_|            "  "               \|_|
    """)
    print("In front of you are: ")
    for item in room_1_content:
        print(item)


def room_1_gameplay():
    global key_a, current_moves, key_a_status, secrets_found
    print(f"ROOM 1                           Turn {current_moves}                           {key_a_status}")
    while True:
        room_1_input = input("What would you like to examine? ").lower()
        if room_1_input not in room_1_content:
            print("That doesn't appear to be in the room. Please try again.")
            continue
        if room_1_input == "piano":
            print("You found the key!")
            key_a = True
            key_a_status = "KEY FOUND"
            current_moves += 1
            print(f"ROOM 1                           Turn {current_moves}                           {key_a_status}")
            continue
        elif room_1_input == "couch":
            print("As you decide to rummage through the couch you've woken up on, all you can find is cigarette butts in between the couch cushions. Try looking around more.")
            current_moves += 1
            print(f"ROOM 1                           Turn {current_moves}                           {key_a_status}")
            continue
        elif room_1_input == "painting":
            print("You lay your eyes upon a crackling oil painting of a decrepit old man, staring menacingly into the observer's gaze. You take it off the wall and notice a note tucked behind the canvas.")
            current_moves += 1
            secrets_found += 1
            print(f"SECRET FOUND                     {secrets_found}/???")
            print(f"ROOM 1                           Turn {current_moves}                           {key_a_status}")
            continue
        elif room_1_input == "wardrobe":
            print("default response for wardrobe. look around more")
            current_moves += 1
            print(f"ROOM 1                           Turn {current_moves}                           {key_a_status}")
            continue
        elif room_1_input == "door a":
            if key_a == False:
                print("locked response for door a. look around more")
                current_moves += 1
                print(f"ROOM 1                           Turn {current_moves}                           {key_a_status}")
                continue
            elif key_a == True:
                return "bedroom_1"
    

def bedroom_1_introduction():
    print("""
         .    !__________!    .    _______
        /_\   |____  ____|   /_\   |__*__|
       __|__  {____}{____}  __|__  |__*__|
     __|_*_|__%%%%%%%%%%%%__|_*_|__|__*__|__
       |   | %%%%%%%%%%%%%% |   |  |/   \|
            %%%%%%%%%%%%%%%%
           %%%%%%%%%%%%%%%%%%
          %%%%%%%%%%%%%%%%%%%%
         /||||||||||||||||||||\
         ||||||||||||||||||lc||
    """)
    print("In front of you are: ")
    for item in bedroom_1_content:
        print(item)

# Add similar functions for room 2 and other rooms
def bedroom_1_gameplay():
    global key_a, key_b, current_moves, key_a_status, key_b_status, secrets_found
    print(f"BEDROOM 1                        Turn {current_moves}                           {key_b_status}")
    while True:
        bedroom_1_input = input("What would you like to examine? ").lower()
        if bedroom_1_input not in bedroom_1_content:
            print("That doesn't appear to be in the room. Please try again.")
            continue
        if bedroom_1_input == "queen bed":
            current_moves += 1
            print("In front of you stands an old bed. Here is what you can look through: ")
            for i in bed:
                print(i)
            bed_input = input("What part of the bed would you like to inspect? ").lower()
            while True:

                if bed_input not in bed:
                    print("That doesn't appear to be on the bed. Please try again.")
                    bed_input = input("What part of the bed would you like to inspect? ").lower()
                    continue
                if bed_input == "sheets":
                    key_b = True
                    key_b_status = "KEY FOUND"
                    print("You found the key! (rewrite this)")
                    print(f"BEDROOM 1                        Turn {current_moves}                           {key_b_status}")
                    break
                else:
                    print("There doesn't appear to be a key here. Try looking around some more.")
                    bed_input = input("What part of the bed would you like to inspect? ").lower()
                    continue
        elif bedroom_1_input == "cabinet":
            print("The cabinet appears to be empty. Look around more.")
            current_moves += 1
            print(f"BEDROOM 1                        Turn {current_moves}                           {key_b_status}")
        elif bedroom_1_input == "rug":
            print("There doesn't look to be anything behind the rug. Look around more.")
            current_moves += 1
            print(f"BEDROOM 1                        Turn {current_moves}                           {key_b_status}")
        elif bedroom_1_input == "mirror":
            print("You notice a small piece of paper tucked behind the mirror.")
            secrets_found += 1
            current_moves += 1
            print(f"SECRET FOUND                     {secrets_found}/???")
            print(f"BEDROOM 1                        Turn {current_moves}                           {key_b_status}")
        elif bedroom_1_input == "door a":
            if secret_knowledge == True and key_a == True: 
                return "good_ending"
            elif secret_knowledge == False and key_a == True:
                return "room_1"
            elif key_a == False:
                print("how did you even manage to get here")
                current_moves += 1
                print(f"BEDROOM 1                        Turn {current_moves}                           {key_b_status}")
        elif bedroom_1_input == "door b":
            if key_b == True:
                return "bedroom_2"
            else:
                print("This door is locked. Try looking for the key.")
                current_moves += 1
                print(f"BEDROOM 1                        Turn {current_moves}                           {key_b_status}")
        elif bedroom_1_input == "door c":
            if key_c == True:
                return "living_room"
            elif key_d == True and key_c == False:
                print("This key doesn't appear to fit the keyhole.")
                current_moves += 1
                print(f"BEDROOM 1                        Turn {current_moves}                           {key_b_status}")
            elif key_d == False and key_c == False:
                print("This door is locked. Try looking for the key.")
                current_moves += 1
                print(f"BEDROOM 1                        Turn {current_moves}                           {key_b_status}")



def bedroom_2_introduction():
    print("""
     _____________________________________________________________________________
    |#############################################################################|
    |#############################################################################|
    |#############################################################################|
    |###############################======================########################|
    |############|_-_-_-_|#########/                      \#######################|
    |############|-_-_-_-|########/  _   !__________!   _  \######################|
    |############|_-_-_-_|#######/| /_\  |____  ____|  /_\ |\#####################|
    |############|-_-_-_-|######/ |__|__ {____}{____} __|__| \####################|
    |############=========######| ||_*_|_%%%%%%%%%%%%_|_*_|| |####################|
    |###########/_________\#####|/ |   |%%%%%%%%%%%%%%|   | \|####################|
    |########=================##|      %%%%%%%%%%%%%%%%      |####################|
    |#########|  =========  |###|     %%%%%%%%%%%%%%%%%%     |####################|
    |.-----.##| /     (   \ |###|    %%%%%%%%%%%%%%%%%%%%    |##.---------------.#|
    ||     |##||     )     ||###|   /||||||||||||||||||||\   |##|       |       |#|
    ||  *  |##|| o  ) (  o ||###|   ||||||||||||||||||||||   |##|   *   |   *   |#|
    || ____|##|| |  ( )) | ||###|                            |#/|_______|______ /lc
    =()_____()||/!\@@@@@/!\||====                            =()/______________()==
     ||_____||===============                                 ||_______________||
     ||     ||                                                ||               ||  
    """)
    print("In front of you are: ")
    for item in bedroom_2_content:
        print(item)

def bedroom_2_gameplay():
    global key_b, key_c, key_d, key_b_status, key_c_status, key_d_status, current_moves, secrets_found
    print(f"BEDROOM 2                        Turn {current_moves}                           {key_c_status}")
    while True:
        bedroom_2_input = input("What would you like to examine? ").lower()
        if bedroom_2_input not in bedroom_2_content:
            print("That doesn't appear to be in the room. Please try again.")
            continue
        if bedroom_2_input == "double bed":
            current_moves += 1
            print("In front of you stands an old bed. Here is what you can look through: ")
            for i in bed:
                print(i)
            bed_input = input("What part of the bed would you like to inspect? ").lower()
            while True:

                if bed_input not in bed:
                    print("That doesn't appear to be on the bed. Please try again.")
                    bed_input = input("What part of the bed would you like to inspect? ").lower()
                    continue
                if bed_input == "bedframe":
                    key_c = True
                    key_c_status = "KEY FOUND"
                    print("You found the key! (rewrite this)")
                    print(f"BEDROOM 2                        Turn {current_moves}                           {key_c_status}")
                    break
                else:
                    print("There doesn't appear to be a key here. Try looking around some more.")
                    bed_input = input("What part of the bed would you like to inspect? ").lower()
                    continue
        elif bedroom_2_input == "dresser":
            current_moves += 1
            print("You open the dresser and are greeted with three old shelves with stuff scattered on it.")
            for i in dresser:
                print(i)
            dresser_input = input("What part of the dresser would you like to inspect? ").lower()
            while True:
                if dresser_input not in dresser:
                    print("That doesn't appear to be in the dresser. Please try again.")
                    dresser_input = input("What part of the dresser would you like to inspect? ").lower()
                    continue
                if dresser_input == "top shelf":
                    key_d = True
                    key_d_status = "KEY FOUND"
                    print("You found the key! (rewrite this)")
                    print(f"BEDROOM 2                        Turn {current_moves}                           {key_d_status}")
                    break
                elif dresser_input == "middle shelf":
                    print("You find a crumpled piece of paper behind a book.")
                    secrets_found += 1
                    print(f"SECRET FOUND                     {secrets_found}/???")
                    break
                else:
                    print("There doesn't appear to be a key here. Try looking around some more.")
                    dresser_input = input("What part of the dresser would you like to inspect? ").lower()
                    continue
        elif bedroom_2_input == "carpet":
            print("There's nothing under the carpet. Look around some more.")
            current_moves += 1
            print(f"BEDROOM 2                        Turn {current_moves}                           {key_c_status}")
        elif bedroom_2_input == "sewing machine":
            print("Why would you ever think there's something hidden in the sewing machine?")
            current_moves += 1
            print(f"BEDROOM 2                        Turn {current_moves}                           {key_c_status}")
        elif bedroom_2_input == "bookshelf":
            print("You notice a piece of a note hidden in one of the books.")
            secrets_found += 1
            current_moves += 1
            print(f"SECRET FOUND                     {secrets_found}/???")
            print(f"BEDROOM 2                        Turn {current_moves}                           {key_c_status}")
        elif bedroom_2_input == "door b":
            return "bedroom_1"
            print(f"LIVING ROOM                      Turn {current_moves}                           {key_d_status}")
            

def living_room_introduction():
    print("""
                            |      |        ,---------,
                            K.    .H        |r'''|'''Y|
                           /  *'.*  \       ||   |   ||
                          /          \      ||===|===||
                         /.-       -. \     ||   |   ||
                        / |-|    _/-/  \    |L.__|__.J|
                       /  \)_)  (_()    \   '---------'
                    _________________________
                     -__LLLLLLLLLLLLLLLLL__-
                      \|#/#############\#|/
                      \|##/           \##|/
                      \|#|  )  ) ( ) ) |#|/
                      \|#|  ( ( ()((   |#|/
                      \|#|   /\__\_(-  |#|/
         _____________\|#| _(\/L/(\/)_ |#|/_____________
                      \|#|-.-.-.-.-.-.-|#|/             
                       '''             '''
        
                         ,_,_,_,_,_,_,_,
                        /   .-.   .-.   \
                       / .-'   '-'   '-. \
                      /-'    .-' '-.    '-\
                      +'+'+'+'+'+'+'+'+'+'+
    """)
    print("In front of you are: ")
    for item in living_room_content:
        print(item)

def living_room_gameplay():
    global key_d, key_d_status, current_moves, secrets_found, secret_knowledge
    while True:
        living_room_input = input("What would you like to examine? ").lower()
        if living_room_input not in living_room_content:
            print("That doesn't appear to be in the room. Please try again.")
            continue
        elif living_room_input == "dining table":
            if secrets_found == 5:
                print("There appears to be a message written on a ripped up note on the table. You take out all the notes that you found and arrange them in a way that appears to make sense, and are faced with the following message: ") 
                print("YOU HAVE EARNED YOU FREEDOM. YOU MAY LEAVE NOW.")
                secret_knowledge = True
                current_moves += 1
                print(f"LIVING ROOM                      Turn {current_moves}                           {key_d_status}")
            else: 
                print("There appears to be a message written on a ripped up note on the table. Some parts look to be missing. You wonder what this is about.")
                current_moves += 1
                print(f"LIVING ROOM                      Turn {current_moves}                           {key_d_status}")
        elif living_room_input == "chair 1":
            print("Wow, this chair sure is old!")
            current_moves += 1
            print(f"LIVING ROOM                      Turn {current_moves}                           {key_d_status}")
        elif living_room_input == "chair 2":
            print("Wow, this chair sure does smell weird!")
            current_moves += 1
            print(f"LIVING ROOM                      Turn {current_moves}                           {key_d_status}")
        elif living_room_input == "chair 3":
            print("You find a ripped up bit of paper on this chair.")
            secrets_found += 1
            print(f"SECRET FOUND                     {secrets_found}/???")
            current_moves += 1
            print(f"LIVING ROOM                      Turn {current_moves}                           {key_d_status}")
        elif living_room_input == "chair 4":
            print("Wow, this chair sure is creaky!")
            current_moves += 1
            print(f"LIVING ROOM                      Turn {current_moves}                           {key_d_status}")
        elif living_room_input == "fireplace":
            print("As you search around the fireplace, you notice a piece of paper hidden between the bricks.")
            secrets_found += 1
            print(f"SECRET FOUND                     {secrets_found}/???")
            current_moves += 1
            print(f"LIVING ROOM                      Turn {current_moves}                           {key_d_status}")
        elif living_room_input == "door c":
            return "bedroom_1"
            print(f"LIVING ROOM                      Turn {current_moves}                           {key_d_status}")
        elif living_room_input == "door d":
            if key_d == True and secret_knowledge == True:
                return "good_ending"
            elif key_d == True and secret_knowledge == False:
                return "bad_ending"
            else: 
                print("This door is locked. Try looking for the key.")
                current_moves += 1
                print(f"LIVING ROOM                      Turn {current_moves}                           {key_d_status}")



def game_bad_ending(): 
    print("YOU DIDN'T LISTEN")
    print("YOU DIDN'T LOOK FOR THE TRUE WAY OUT")
    print("""
    ⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
    ⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
    ⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
    ⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
    ⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡿⠿⠿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
    ⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡿⢉⠀⠀⠀⠙⢿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡟⠁⠀⠀⠀⠀⠹⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
    ⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡅⠀⠀⠀⠀⠀⢸⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡇⠀⠀⠀⠀⠀⢠⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
    ⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣷⣄⠀⠄⠀⣠⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣦⣀⣉⣁⣴⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
    ⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
    ⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
    ⣿⣿⣿⣿⣿⣿⣿⣿⢿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
    ⣿⣿⣿⣿⣿⣿⣿⣿⣈⡏⠹⡟⢿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⠛⢻⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
    ⣿⣿⣿⣿⣿⣿⣿⣿⡿⣿⣦⡀⠀⠈⣿⠛⠿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⠟⠛⠃⣰⣾⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
    ⣿⣿⣿⣿⣿⣿⣿⣿⣷⣿⠘⣿⣤⡀⢀⡀⠀⠀⠉⠻⡟⣿⣿⣿⡿⢿⣿⣿⣿⣿⣿⣿⣿⡿⢿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡿⠟⠋⢉⣁⣡⣤⣴⡾⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
    ⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣧⣾⣹⣿⣾⢿⣆⣠⠀⠀⢁⠈⣿⡿⠀⠈⣿⠟⠀⠈⠹⣿⡏⠀⠀⠈⣿⡟⠁⠸⣿⠃⣼⣏⢀⡆⣴⣿⣿⡟⡅⣿⢱⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
    ⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣷⣹⣿⡿⢿⣶⣷⣼⣷⣟⠁⠀⠀⡟⠀⠀⠀⠀⣽⡇⠀⠀⠀⠨⠄⠀⠀⢙⡀⢃⣸⣾⣿⣼⣿⢸⣧⣷⣿⣾⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
    ⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣧⣿⣷⡈⣷⡈⣻⣿⣼⣦⣀⣰⠃⠀⠀⠀⠀⠙⠁⠀⡀⠀⠊⣠⣀⣤⣾⣷⡌⣯⣿⢟⡟⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
    ⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡺⠇⢹⣿⣿⣿⡿⣿⣤⣀⣀⣤⣤⣴⣄⠀⠃⣄⣀⢿⡿⠛⠿⣿⠙⣿⣷⣼⣧⣾⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
    ⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣷⣿⣾⠹⣿⡿⠁⢹⡃⠈⠉⣿⠁⠊⡿⠀⠈⣿⠀⢸⡇⠀⠀⢿⡄⠹⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
    ⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣦⣿⠁⣠⣾⠇⠀⢠⣧⠀⢠⡇⠀⢀⣿⡀⢸⣇⠀⢠⣸⣷⣤⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
    ⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣶⣿⣿⣦⣠⣾⣿⣶⣾⣷⣤⣸⣿⣿⣾⣿⣾⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
    ⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
    ⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
    ⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
    ⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
    """)
    print("GAME OVER")
    print(f"TOTAL MOVES: {current_moves}                         SECRETS FOUND: {secrets_found}")

def game_good_ending():
    print("""
                                                      ,           ^'^  _
                                                  )               (_) ^'^
             _/\_                    .---------. ((        ^'^
             (('>                    )`'`'`'`'`( ||                 ^'^
        _    /^|                    /`'`'`'`'`'`\||           ^'^
        =>--/__|m---               /`'`'`'`'`'`'`\|
             ^^           ,,,,,,, /`'`'`'`'`'`'`'`\      ,
                         .-------.`|`````````````|`  .   )
                        / .^. .^. \|  ,^^, ,^^,  |  / \ ((
                       /  |_| |_|  \  |__| |__|  | /,-,\||
            _         /_____________\ |")| |  |  |/ |_| \|
           (")         |  __   __  |  '==' '=='  /_______\     _
          (' ')        | /  \ /  \ |   _______   |,^, ,^,|    (")
           \  \        | |--| |--| |  ((--.--))  ||_| |_||   (' ')
         _  ^^^ _      | |__| |("| |  ||  |  ||  |,-, ,-,|   /  /
       ,' ',  ,' ',    |           |  ||  |  ||  ||_| |_||   ^^^
    .,,|RIP|,.|RIP|,.,,'==========='==''=='==''=='=======',,....,,,,.,
    """)
    print("YOU ESCAPED")
    print(f"TOTAL MOVES: {current_moves}                         SECRETS FOUND: {secrets_found}")
                               
# Main game loop
print("You wake up on a grimey black leather couch of a seemingly unfamiliar room. As your brain begins processing the situation, you are saddled with the realization that you are stuck here with no clear way to escape. The windows are boarded shut and the door is ornamented with a dramatically large padlock, almost to drive home the notion that you are stuck in here for good. Seeing no better option, you decide to look around and examine the contents of the room as an attempt to escape.")
current_room = "room_1"
while True:
    if current_room == "room_1":
        room_1_introduction()
        current_room = room_1_gameplay()
        print(f"###########################################################################\nLEAVING ROOM A")
        continue
    elif current_room == "bedroom_1":
        bedroom_1_introduction()
        current_room = bedroom_1_gameplay()
        print(f"###########################################################################\nLEAVING ROOM B")
        continue
    elif current_room == "bedroom_2":
        bedroom_2_introduction()
        current_room = bedroom_2_gameplay()
        print(f"###########################################################################\nLEAVING ROOM C")
        continue
    elif current_room == "living_room":
        living_room_introduction()
        current_room = living_room_gameplay()
        print(f"###########################################################################\nLEAVING ROOM D")
        continue
    elif current_room == "bad_ending":
        game_bad_ending()
        break
    elif current_room == "good_ending":
        game_good_ending()
        break
    # Add similar code for other rooms
# Out:
# You wake up on a grimey black leather couch of a seemingly unfamiliar room. As your brain begins processing the situation, you are saddled with the realization that you are stuck here with no clear way to escape. The windows are boarded shut and the door is ornamented with a dramatically large padlock, almost to drive home the notion that you are stuck in here for good. Seeing no better option, you decide to look around and examine the contents of the room as an attempt to escape.
#
#          ____________________________________
#         |\                                            | \                                            |  \____________________________________        |  |       __---_ _---__                |
#         |  |      |======|=====|                |
#         |  |      |======|=====|                |
#         |  |  ____|__---_|_---_|______________  |
#         |  | |                                | |
# ...
